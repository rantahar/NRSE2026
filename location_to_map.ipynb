# %%
import niimpy
from niimpy.preprocessing import location
from niimpy.analysis import social_signature
import pandas
import folium

# %%
data = niimpy.reading.google_takeout.location_history(
    "takeout-20241111T082655Z-001.zip",
    start_date = pandas.to_datetime("2022-01-01", utc=True),
    end_date = pandas.to_datetime("2022-06-30", utc=True),
)
data = niimpy.preprocessing.location.filter_location(
    data,
    remove_disabled=False, remove_network=False, remove_zeros=True
)
data.head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 data = niimpy.reading.google_takeout.location_history(
#       2     "takeout-20241111T082655Z-001.zip",
#       3     start_date = pandas.to_datetime("2022-01-01", utc=True),
#       4     end_date = pandas.to_datetime("2022-06-30", utc=True),
#       5 )
#       6 data = niimpy.preprocessing.location.filter_location(
#       7     data,
#       8     remove_disabled=False, remove_network=False, remove_zeros=True
#       9 )
#      10 data.head(5)
#
# File ~/.local/share/mamba/envs/NRSE2025/lib/python3.12/site-packages/niimpy/reading/google_takeout.py:178, in location_history(zip_filename, inferred_activity, activity_threshold, drop_columns, user, start_date, end_date, timezone)
#     176 filename = "Takeout/Location History (Timeline)/Records.json"
#     177 if start_date is not None:
# --> 178     json_data = read_json_after_timestamp(zip_file, filename, start_date)
#     179 else:
#     180     json_data  = zip_file.read(filename)
#
# File ~/.local/share/mamba/envs/NRSE2025/lib/python3.12/site-packages/niimpy/reading/google_takeout.py:111, in read_json_after_timestamp(zip_file, filename, start_date)
#     109 entry += char
#     110 entry = json.loads(entry)
# --> 111 if pd.to_datetime(entry["timestamp"], format='ISO8601') > start_date:
#     112     data.append(entry)
#     113 entry = ""
#
# File ~/.local/share/mamba/envs/NRSE2025/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:1106, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1104         result = convert_listlike(argc, format)
#    1105 else:
# -> 1106     result = convert_listlike(np.array([arg]), format)[0]
#    1107     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1108         result = bool(result)  # TODO: avoid this kludge.
#
# File ~/.local/share/mamba/envs/NRSE2025/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File ~/.local/share/mamba/envs/NRSE2025/lib/python3.12/site-packages/pandas/core/tools/datetimes.py:469, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     458 def _array_strptime_with_fallback(
#     459     arg,
#     460     name,
#    (...)    464     errors: str,
#     465 ) -> Index:
#     466     """
#     467     Call array_strptime, with fallback behavior depending on 'errors'.
#     468     """
# --> 469     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     470     if tz_out is not None:
#     471         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:330, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:99, in pandas._libs.tslibs.strptime.format_is_iso()
#
# File ~/.local/share/mamba/envs/NRSE2025/lib/python3.12/re/__init__.py:226, in compile(pattern, flags)
#     220     """Return an iterator over all non-overlapping matches in the
#     221     string.  For each match, the iterator returns a Match object.
#     222
#     223     Empty matches are included in the result."""
#     224     return _compile(pattern, flags).finditer(string)
# --> 226 def compile(pattern, flags=0):
#     227     "Compile a regular expression pattern, returning a Pattern object."
#     228     return _compile(pattern, flags)
#
# KeyboardInterrupt:

# %%
location.location_significant_place_features(data)
# Out:
#                            n_sps  n_top2  n_top5  n_moving  n_rare  \
# timestamp
# 2022-04-30 00:00:00+00:00    3.0    31.0     0.0      31.0     2.0
# 2022-05-31 00:00:00+00:00   16.0   543.0    74.0    1477.0    19.0
# 2022-06-30 00:00:00+00:00   37.0   302.0    82.0    1992.0    70.0
#
#                            max_dist_home  n_static  n_transitions  n_top1  \
# timestamp
# 2022-04-30 00:00:00+00:00    5353.427305     136.0            5.0    92.0
# 2022-05-31 00:00:00+00:00   40346.976685    4343.0           81.0  3126.0
# 2022-06-30 00:00:00+00:00  605332.009054    3172.0          164.0  1770.0
#
#                                device                                  user  \
# timestamp
# 2022-04-30 00:00:00+00:00  1832214273  03ae8968-3229-11f0-b8a9-1f7c4541e218
# 2022-05-31 00:00:00+00:00  1832214273  03ae8968-3229-11f0-b8a9-1f7c4541e218
# 2022-06-30 00:00:00+00:00  1832214273  03ae8968-3229-11f0-b8a9-1f7c4541e218
#
#                            normalized_entropy  n_top4  n_home   entropy  \
# timestamp
# 2022-04-30 00:00:00+00:00            4.330821     2.0    91.0  4.757893
# 2022-05-31 00:00:00+00:00            2.423967    94.0   141.0  6.720663
# 2022-06-30 00:00:00+00:00            2.155481   106.0   170.0  7.783265
#
#                            n_top3
# timestamp
# 2022-04-30 00:00:00+00:00    11.0
# 2022-05-31 00:00:00+00:00   200.0
# 2022-06-30 00:00:00+00:00   136.0

# %%
location.find_home(data["latitude"], data["longitude"], data.index)
# Out:
# (np.float64(60.22989181622235), np.float64(24.77360194254112))

# %%
trip_data = data.loc["2022-05-15 12:10:00":"2022-05-15 15:50:00", ["latitude", "longitude"]]
trip_data = trip_data.resample("5min").mean().dropna()
locations = trip_data[["latitude", "longitude"]].drop_duplicates()
map_center = [locations['latitude'].mean(), locations['longitude'].mean()]
mymap = folium.Map(location=map_center, zoom_start=12)

folium.PolyLine(locations[['latitude', 'longitude']].values, color="blue", weight=2.5, opacity=1).add_to(mymap)

for _, row in locations.iterrows():
    folium.Marker(location=[row['latitude'], row['longitude']]).add_to(mymap)

mymap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b3f6bd300b07665ab455c410085b06de {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b3f6bd300b07665ab455c410085b06de&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b3f6bd300b07665ab455c410085b06de = L.map(
#                 &quot;map_b3f6bd300b07665ab455c410085b06de&quot;,
#                 {
#                     center: [60.19341148336785, 24.87501220903717],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ba58d122e8583758b77eb391ef28f560 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ba58d122e8583758b77eb391ef28f560.addTo(map_b3f6bd300b07665ab455c410085b06de);
#
#
#             var poly_line_1d42ce0be32f51871d36f57b9ac47e60 = L.polyline(
#                 [[60.21845405714286, 24.811025714285712], [60.217644525, 24.81076775], [60.21880198, 24.81098952], [60.21883651428571, 24.811765028571426], [60.21701414, 24.8189785], [60.200705414285714, 24.88215955714286], [60.1946131, 24.8844424], [60.19082626666667, 24.882045133333335], [60.189083600000004, 24.8850969], [60.1889401, 24.8850594], [60.1868655, 24.8814117], [60.1869399, 24.8752368], [60.18544970000001, 24.88423555], [60.184034, 24.887068566666667], [60.1840297, 24.8870679], [60.18361256666666, 24.886142266666667], [60.1836221, 24.8860195], [60.1835747, 24.8865061], [60.18162304, 24.88723871], [60.181410911111115, 24.887343], [60.18125226111111, 24.88745423888889], [60.180101005263154, 24.888640884210524], [60.180090316666664, 24.888760077777775], [60.18010575, 24.888769994444445], [60.180107873684214, 24.88876691578947], [60.18009661111111, 24.888763827777776], [60.1800949888889, 24.888762805555555], [60.18151315, 24.88775526111111], [60.18432266999999, 24.886781335000002], [60.18605497647059, 24.88457892352941], [60.187901739999994, 24.88513902], [60.187594499999996, 24.893235966666666], [60.1868557, 24.898719749999998], [60.18797227142857, 24.901738757142855], [60.1895232, 24.900331116666667], [60.19182262500001, 24.896903875000003], [60.19447611333333, 24.891784466666664], [60.20223346666666, 24.88203706666667], [60.2157823, 24.874725433333335], [60.2232127, 24.8630609], [60.225235, 24.8499815], [60.22085126666667, 24.803220666666665]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 2.5}
#             ).addTo(map_b3f6bd300b07665ab455c410085b06de);
#
#
#             var marker_84961740ff9a8ad36e6ba0ae2e26f15f = L.marker(
#                 [60.21845405714286, 24.811025714285712],
#                 {
# }
#             ).addTo(map_b3f6bd300b07665ab455c410085b06de);
#
#
#             var marker_4de0dcaf576101946da1a3dd4986eb17 = L.marker(
#                 [60.217644525, 24.81076775],
#                 {
# }
#             ).addTo(map_b3f6bd300b07665ab455c410085b06de);
#
#
#             var marker_aeb6bf46e8c70f101f2bbaa27161a725 = L.marker(
#                 [60.21880198, 24.81098952],
#                 {
# }
#             ).addTo(map_b3f6bd300b07665ab455c410085b06de);
#
#
#             var marker_d60909e023c13daa06133a0f7d240e66 = L.marker(
#                 [60.21883651428571, 24.811765028571426],
#                 {
# }
#             ).addTo(map_b3f6bd300b07665ab455c410085b06de);
#
#
#             var marker_2004b0478b3a6230b511f1bbc176de2a = L.marker(
#                 [60.21701414, 24.8189785],
#                 {
# }
#             ).addTo(map_b3f6bd300b07665ab455c410085b06de);
#
#
#             var marker_547061b2804c5fbb090a3ed3718afd2a = L.marker(
#                 [60.200705414285714, 24.88215955714286],
#                 {
# }
#             ).addTo(map_b3f6bd300b07665ab455c410085b06de);
#
#
#             var marker_ee07a59080cebf2b259ef9094f6d2c4b = L.marker(
#                 [60.1946131, 24.8844424],
#                 {
# }
#             ).addTo(map_b3f6bd300b07665ab455c410085b06de);
#
#
#             var marker_bde4de103fea2ab1169109d9e51b794f = L.marker(
#                 [60.19082626666667, 24.882045133333335],
#                 {
# }
#             ).addTo(map_b3f6bd300b07665ab455c410085b06de);
#
#
#             var marker_45b87c7cb0b15771f9758ffb9c13b7f5 = L.marker(
#                 [60.189083600000004, 24.8850969],
#                 {
# }
#             ).addTo(map_b3f6bd300b07665ab455c410085b06de);
#
#
#             var marker_63b0dbbb84b9f29a17b4097e0aeef41a = L.mark

# %%
mail_data = niimpy.reading.google_takeout.email_activity(
    "takeout-20241111T082655Z-001.zip",
    start_date = pandas.to_datetime("2022-10-01", utc=True),
)
mail_data
# Out:
# Failed to decode message: decode() argument 'encoding' must be str, not None
#                                             received  from          to  cc  \
# timestamp
# 2024-11-09 09:59:28+00:00  2024-11-09 01:59:29-08:00   989         [0]  []
# 2024-11-04 10:29:41+00:00  2024-11-04 02:29:42-08:00     7         [0]  []
# 2024-11-01 06:44:12+00:00  2024-10-31 23:44:13-07:00     7         [0]  []
# 2024-10-31 00:39:39+00:00  2024-10-30 17:39:42-07:00   184         [0]  []
# 2024-10-29 15:42:27+00:00  2024-10-29 08:42:29-07:00   610         [0]  []
# ...                                              ...   ...         ...  ..
# 2023-07-14 01:40:06+00:00  2023-07-13 18:41:11-07:00   911      [1039]  []
# 2024-08-10 14:20:10+00:00  2024-08-10 07:20:24-07:00   321  [460, 321]  []
# 2024-07-11 18:00:32+00:00  2024-07-11 11:00:53-07:00   631       [631]  []
# 2024-09-06 14:32:10+00:00  2024-09-06 07:33:44-07:00   923         [0]  []
# 2023-06-17 13:16:24+00:00  2023-06-17 06:16:26-07:00    95         [0]  []
#
#                           bcc  message_id in_reply_to  character_count  \
# timestamp
# 2024-11-09 09:59:28+00:00  []        1423        2444              607
# 2024-11-04 10:29:41+00:00  []        3857        <NA>             2225
# 2024-11-01 06:44:12+00:00  []        2847        <NA>             1336
# 2024-10-31 00:39:39+00:00  []        1753        <NA>             1735
# 2024-10-29 15:42:27+00:00  []        2009        3247              403
# ...                        ..         ...         ...              ...
# 2023-07-14 01:40:06+00:00  []        3829        3409              461
# 2024-08-10 14:20:10+00:00  []        1317        2201             6370
# 2024-07-11 18:00:32+00:00  []        1601        3881             2269
# 2024-09-06 14:32:10+00:00  []        1909         712             3493
# 2023-06-17 13:16:24+00:00  []        1338        <NA>             3540
#
#                            word_count message_type  \
# timestamp
# 2024-11-09 09:59:28+00:00          57     incoming
# 2024-11-04 10:29:41+00:00         262     incoming
# 2024-11-01 06:44:12+00:00         146     incoming
# 2024-10-31 00:39:39+00:00         170     incoming
# 2024-10-29 15:42:27+00:00          13     incoming
# ...                               ...          ...
# 2023-07-14 01:40:06+00:00          73     incoming
# 2024-08-10 14:20:10+00:00         891     incoming
# 2024-07-11 18:00:32+00:00         213     incoming
# 2024-09-06 14:32:10+00:00         169     incoming
# 2023-06-17 13:16:24+00:00         209     incoming
#
#                                                            user
# timestamp
# 2024-11-09 09:59:28+00:00  307848e4-3229-11f0-b8a9-1f7c4541e218
# 2024-11-04 10:29:41+00:00  307848e4-3229-11f0-b8a9-1f7c4541e218
# 2024-11-01 06:44:12+00:00  307848e4-3229-11f0-b8a9-1f7c4541e218
# 2024-10-31 00:39:39+00:00  307848e4-3229-11f0-b8a9-1f7c4541e218
# 2024-10-29 15:42:27+00:00  307848e4-3229-11f0-b8a9-1f7c4541e218
# ...                                                         ...
# 2023-07-14 01:40:06+00:00  307848e4-3229-11f0-b8a9-1f7c4541e218
# 2024-08-10 14:20:10+00:00  307848e4-3229-11f0-b8a9-1f7c4541e218
# 2024-07-11 18:00:32+00:00  307848e4-3229-11f0-b8a9-1f7c4541e218
# 2024-09-06 14:32:10+00:00  307848e4-3229-11f0-b8a9-1f7c4541e218
# 2023-06-17 13:16:24+00:00  307848e4-3229-11f0-b8a9-1f7c4541e218
#
# [3620 rows x 11 columns]

# %%
signature = social_signature.social_signature(mail_data)
signature.head(10)
# Out:
# contact
# 184    0.084448
# 906    0.053930
# 610    0.035953
# 394    0.035535
# 643    0.030518
# 7      0.025920
# 98     0.025084
# 154    0.024247
# 772    0.024247
# 8      0.022157
# dtype: float64

# %%
signature = social_signature.social_signature(mail_data, include_received=False)
signature.head(10)
# Out:
# contact
# 41      0.166667
# 733     0.166667
# 154     0.083333
# 930     0.055556
# 356     0.055556
# 1057    0.055556
# 341     0.055556
# 957     0.055556
# 299     0.027778
# 335     0.027778
# dtype: float64
